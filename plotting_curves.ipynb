# %%
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(np.pi, 8*np.pi,50)
plt.plot(x, np.sin(x))

# %%
def get_noise(shape, mean = 0.5):
    return np.random.normal(0, mean, shape)

# %%
noisy_x = np.linspace(np.pi, 8*np.pi, 20)
# noise = get_noise(noisy_x.shape)
noise = get_noise(20)

plt.plot(noisy_x, noise)

# %%
noisy_xt = np.linspace(4*np.pi, 8*np.pi, 10)
full_x = np.concatenate((noisy_x , x, noisy_xt))
full_y = np.concatenate((get_noise(noisy_x.shape), np.sin(x), get_noise(noisy_xt.shape)))
plt.plot(full_x, full_y)

# %%
full_x = np.concatenate((noisy_x , x, ))
full_y = np.concatenate((np.tanh(noisy_x)+noise, np.sin(x)))
plt.plot(full_x, full_y)

# %%
from dataloader import NoisySineDataset

# %%
k = NoisySineDataset()

# %%
x, y = next(iter(k))
plt.plot(x, y)

# %%
y
# Out:
# array([ 0.   ,  0.491,  0.855,  0.999,  0.887,  0.546,  0.064, -0.434,
#        -0.82 , -0.995, -0.914, -0.598, -0.128,  0.375,  0.782,  0.987,
#         0.938,  0.648,  0.191, -0.315, -0.74 , -0.975, -0.959, -0.696,
#        -0.254,  0.254,  0.696,  0.959,  0.975,  0.74 ,  0.315, -0.191,
#        -0.648, -0.938, -0.987, -0.782, -0.375,  0.128,  0.598,  0.914,
#         0.995,  0.82 ,  0.434, -0.064, -0.546, -0.887, -0.999, -0.855,
#        -0.491, -0.   , -0.607,  0.022,  0.39 , -0.824,  0.023,  0.823,
#         0.338, -0.604,  0.117,  0.019, -0.384,  0.885, -0.017,  0.109,
#        -0.727, -0.478, -0.277, -0.041,  0.84 ,  0.498, -0.271, -0.291,
#        -0.037, -0.147, -0.184, -1.56 , -0.058,  0.635, -0.659, -0.232,
#         0.18 ,  0.486,  0.095, -0.104,  0.578, -1.061,  0.024,  1.052,
#         0.139, -0.045])

# %%
from dataloader import CleanSineDataset

# %%
c = CleanSineDataset()
x, y = next(iter(c))
plt.plot(x, y)
